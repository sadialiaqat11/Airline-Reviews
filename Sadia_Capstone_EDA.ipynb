# %% [markdown]
# # Reading the Data

# %%
#importing the libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
pd.set_option("display.max_rows", 500)
pd.set_option("display.max_columns", 500)

# %%
# Having a look at the data
airlines_df=pd.read_csv("Airline_review.csv")
airlines_df
# Out:
#         Airline Name Overall_Rating                            Review_Title  \
# 0        AB Aviation              9                 "pretty decent airline"
# 1        AB Aviation              1                    "Not a good airline"
# 2        AB Aviation              1          "flight was fortunately short"
# 3      Adria Airways              1     "I will never fly again with Adria"
# 4      Adria Airways              1   "it ruined our last days of holidays"
# ...              ...            ...                                     ...
# 23166         ZIPAIR              1          "customer service is terrible"
# 23167         ZIPAIR              1                    "Avoid at all costs"
# 23168         ZIPAIR              3          "Will not recommend to anyone"
# 23169         ZIPAIR              6             "It was immaculately clean"
# 23170         ZIPAIR              1  "lost all of our money with no refund"
#
#                Review Date  Verified  \
# 0       11th November 2019      True
# 1           25th June 2019      True
# 2           25th June 2019      True
# 3      28th September 2019     False
# 4      24th September 2019      True
# ...                    ...       ...
# 23166        5th July 2022     False
# 23167        1st June 2022      True
# 23168        31st May 2022      True
# 23169        23rd May 2022      True
# 23170        20th May 2022      True
#
#                                                   Review Type Of Traveller  \
# 0        Moroni to Moheli. Turned out to be a pretty ...      Solo Leisure
# 1       Moroni to Anjouan. It is a very small airline...      Solo Leisure
# 2        Anjouan to Dzaoudzi. A very small airline an...      Solo Leisure
# 3        Please do a favor yourself and do not fly wi...      Solo Leisure
# 4       Do not book a flight with this airline! My fr...    Couple Leisure
# ...                                                  ...               ...
# 23166   Bangkok to Tokyo. I’ve flown many low cost ai...    Couple Leisure
# 23167    Avoid at all costs. I booked flights to go f...      Solo Leisure
# 23168    Flight was leaving at 23.15 and after an hou...          Business
# 23169   Zipair is JAL’s budget airline. They don’t ha...          Business
# 23170    They lied about connection in Narita and we ...      Solo Leisure
#
#             Seat Type                             Route Date Flown  \
# 0       Economy Class                  Moroni to Moheli     Nov-19
# 1       Economy Class                 Moroni to Anjouan     Jun-19
# 2       Economy Class               Anjouan to Dzaoudzi     Jun-19
# 3       Economy Class             Frankfurt to Pristina     Sep-19
# 4       Economy Class  Sofia to Amsterdam via Ljubljana     Sep-19
# ...               ...                               ...        ...
# 23166   Economy Class                  Bangkok to Tokyo     Jun-22
# 23167   Economy Class                Singapore to Tokyo     Jun-22
# 23168   Economy Class                  Bangkok to Tokyo     May-22
# 23169  Business Class              Tokyo to Los Angeles     May-22
# 23170   Economy Class                Singapore to Tokyo     May-22
#
#        Seat Comfort  Cabin Staff Service  Food & Beverages  Ground Service  \
# 0               4.0                  5.0               4.0             4.0
# 1               2.0                  2.0               1.0             1.0
# 2               2.0                  1.0               1.0             1.0
# 3               1.0                  1.0               NaN             1.0
# 4               1.0                  1.0               1.0             1.0
# ...             ...                  ...               ...             ...
# 23166           2.0                  1.0               NaN             1.0
# 23167           NaN                  NaN               NaN             NaN
# 23168           2.0                  4.0               2.0             1.0
# 23169           3.0                  4.0               3.0             1.0
# 23170           NaN                  NaN               NaN             1.0
#
#        Value For Money Recommended
# 0                  3.0         yes
# 1                  2.0          no
# 2                  2.0          no
# 3                  1.0          no
# 4                  1.0          no
# ...                ...         ...
# 23166              1.0          no
# 23167              1.0          no
# 23168              2.0          no
# 23169              5.0         yes
# 23170              1.0          no
#
# [23171 rows x 16 columns]

# %%
#to check the number of rows and columns
airlines_df.shape
# Out:
# (23171, 16)

# %%
#columns only
airlines_df.shape[0]
# Out:
# 23171

# %%
#Checking the nulls percentage
airlines_df.isnull().sum()/airlines_df.shape[0]
# Out:
# Airline Name           0.000000
# Overall_Rating         0.000000
# Review_Title           0.000000
# Review Date            0.000000
# Verified               0.000000
# Review                 0.000000
# Type Of Traveller      0.161322
# Seat Type              0.047301
# Route                  0.165207
# Date Flown             0.162013
# Seat Comfort           0.179319
# Cabin Staff Service    0.183851
# Food & Beverages       0.374218
# Ground Service         0.206853
# Value For Money        0.046006
# Recommended            0.000000
# dtype: float64

# %%
# Checking number of airlines
airlines_df["Airline Name"].nunique()
# Out:
# 497

# %%
#Checking the number of reviews for each airline
airlines= airlines_df["Airline Name"].value_counts()
airlines
# Out:
# Airline Name
# Caribbean Airlines                  100
# GoAir                               100
# Germanwings                         100
# Philippine Airlines                 100
# Bangkok Airways                     100
# Garuda Indonesia                    100
# Batik Air                           100
# Swoop                               100
# Frontier Airlines                   100
# Sunwing Airlines                    100
# Sun Country Airlines                100
# Blue Air                            100
# FlySafair                           100
# PLAY                                100
# flydubai                            100
# Porter Airlines                     100
# Qantas Airways                      100
# SriLankan Airlines                  100
# Flair Airlines                      100
# Go First                            100
# TAM Airlines                        100
# British Airways                     100
# Pegasus Airlines                    100
# American Airlines                   100
# American Eagle                      100
# Egyptair                            100
# Thomson Airways                     100
# Thomas Cook Airlines                100
# Thai Smile Airways                  100
# Oman Air                            100
# Onur Air                            100
# Thai Lion Air                       100
# Asiana Airlines                     100
# Hawaiian Airlines                   100
# Thai Airways                        100
# TAP Portugal                        100
# Hainan Airlines                     100
# Austrian Airlines                   100
# Avianca                             100
# Gulf Air                            100
# Breeze Airways                      100
# Brussels Airlines                   100
# Tigerair Australia                  100
# Eurowings                           100
# Condor Airlines                     100
# Ethiopian Airlines                  100
# Copa Airlines                       100
# Royal Air Maroc                     100
# Royal Brunei Airlines               100
# CSA Czech Airlines                  100
# Cubana Airlines                     100
# Royal Jordanian Airlines            100
# Delta Air Lines                     100
# Scoot                               100
# Saudi Arabian Airlines              100
# Dragonair                           100
# SATA Air Azores                     100
# Emirates                            100
# El Al Israel Airlines               100
# Ryanair                             100
# easyJet                             100
# Etihad Airways                      100
# EVA Air                             100
# Spirit Airlines                     100
# CityJet                             100
# Bulgaria Air                        100
# SpiceJet                            100
# Southwest Airlines                  100
# South African Airways               100
# Finnair                             100
# LIAT                                100
# Fiji Airways                        100
# QantasLink                          100
# Cathay Pacific Airways              100
# Qatar Airways                       100
# Cebu Pacific                        100
# Singapore Airlines                  100
# Silver Airways                      100
# China Airlines                      100
# China Eastern Airlines              100
# China Southern Airlines             100
# SilkAir                             100
# Tigerair                            100
# ANA All Nippon Airways              100
# Edelweiss Air                       100
# United Airlines                     100
# Air Europa                          100
# Wizz Air                            100
# Aeromexico                          100
# WOW air                             100
# Air France                          100
# Virgin America                      100
# Vietnam Airlines                    100
# Air India                           100
# Allegiant Air                       100
# Lynx Air                            100
# Malaysia Airlines                   100
# Jetstar Pacific                     100
# Jetstar Asia                        100
# US Airways                          100
# Jetstar Airways                     100
# LATAM Airlines                      100
# Virgin Australia                    100
# Vistara                             100
# Volaris                             100
# Air Astana                          100
# Korean Air                          100
# Volotea                             100
# Air Berlin                          100
# KLM Royal Dutch Airlines            100
# Kuwait Airways                      100
# Kenya Airways                       100
# LAN Airlines                        100
# LOT Polish Airlines                 100
# Air Canada                          100
# Air Canada rouge                    100
# Lufthansa                           100
# Air China                           100
# VivaAerobús                         100
# Malindo Air                         100
# Air Malta                           100
# Vueling Airlines                    100
# airBaltic                           100
# Interjet                            100
# AirAsia                             100
# AirAsia India                       100
# Aer Lingus                          100
# AirAsia X                           100
# Aegean Airlines                     100
# Icelandair                          100
# ITA Airways                         100
# Nok Air                             100
# Iberia                              100
# Norwegian                           100
# Hong Kong Airlines                  100
# Alaska Airlines                     100
# Alitalia                            100
# Air Mauritius                       100
# Air Transat                         100
# Air Tahiti Nui                      100
# Jet2.com                            100
# Jetblue Airways                     100
# Turkish Airlines                    100
# Aerolineas Argentinas               100
# Xiamen Airlines                     100
# Aeroflot Russian Airlines           100
# Air New Zealand                     100
# Lion Air                            100
# Jet Airways                         100
# Meridiana                           100
# Monarch Airlines                    100
# Transavia                           100
# Air Serbia                          100
# Japan Airlines                      100
# Air Arabia                          100
# Thai AirAsia                         99
# Avelo Airlines                       95
# Olympic Air                          93
# SmartWings                           92
# Adria Airways                        91
# Rwandair                             91
# Croatia Airlines                     90
# Regional Express                     87
# Luxair                               86
# Kulula                               85
# Air Namibia                          83
# French Bee                           82
# Tunisair                             80
# Sky Express Airlines                 78
# XL Airways France                    78
# Air Dolomiti                         78
# Air India Express                    78
# Firefly                              76
# Insel Air                            76
# AirAsia Philippines                  75
# Level                                74
# Air Seychelles                       74
# TUI Airways                          73
# Lao Airlines                         72
# Uzbekistan Airways                   72
# BA CityFlyer                         72
# Shanghai Airlines                    72
# Viva Air                             70
# Iberia Express                       69
# Azerbaijan Airlines                  68
# Iran Air                             66
# S7 Siberia Airlines                  66
# TUIfly                               65
# Openskies                            65
# Eastern Airways                      63
# Aurigny Air                          62
# Cathay Dragon                        62
# TAAG Angola Airlines                 62
# Citilink                             60
# Peach Aviation                       60
# bmi Regional                         58
# Bahamasair                           57
# Norse Atlantic Airways               57
# Sriwijaya Air                        55
# Georgian Airways                     55
# Transaero Airlines                   55
# Arik Air                             54
# Flynas                               54
# Air Koryo                            54
# Jazeera Airways                      52
# Air Niugini                          52
# Akasa Air                            51
# Rex Airlines                         51
# Airlink                              50
# ZIPAIR                               50
# Comair                               50
# Sky Airline                          49
# Sichuan Airlines                     49
# Corsair                              48
# Air Algerie                          48
# VivaColombia                         48
# Blue Islands                         48
# Corendon Airlines                    47
# Air Austral                          47
# VLM Airlines                         46
# SA Express                           45
# La Compagnie                         45
# Belavia                              45
# Air Nostrum                          44
# Estonian Air                         44
# Rossiya Airlines                     44
# Air Moldova                          43
# Peruvian Airlines                    43
# LAN Peru                             42
# NIKI                                 42
# Shenzhen Airlines                    42
# Aircalin                             42
# Cape Air                             41
# Turkmenistan Airlines                40
# Jetstar Japan                        40
# Phuket Air                           40
# Arkefly                              40
# Pobeda Airlines                      38
# SkyWest Airlines                     38
# Boutique Air                         38
# Karthago Airlines                    38
# Bamboo Airways                       37
# TAME                                 37
# Laudamotion                          35
# Blue Panorama Airlines               35
# Fly540.com                           34
# fastjet                              33
# Nepal Airlines                       33
# Loganair                             32
# Air Italy                            31
# AirAsia Zest                         31
# Mahan Air                            30
# Titan Airways                        30
# Alliance Air                         30
# Afriqiyah Airways                    29
# Air Madagascar                       28
# Kam Air                              28
# Blue1                                27
# Myanmar Airways                      27
# Airnorth                             26
# Air Macau                            25
# Horizon Air                          25
# Yemenia                              24
# Air Zimbabwe                         24
# Cayman Airways                       24
# Israir Airlines                      24
# Air Caraibes                         24
# Shandong Airlines                    24
# Air Botswana                         23
# Wideroe                              23
# ASKY Airlines                        23
# Surinam Airways                      23
# Air Juan                             23
# SyrianAir                            23
# Regent Airways                       22
# Martinair                            22
# Wingo                                22
# Jetairfly                            22
# Jeju Air                             22
# Hi Fly                               22
# AnadoluJet                           22
# Wings Air                            21
# Druk Air                             20
# Air Busan                            20
# Air Memphis                          20
# Air Tanzania                         20
# Jin Air                              20
# Ural Airlines                        19
# Germania Airline                     19
# Montenegro Airlines                  19
# flyadeal                             19
# Ravn Alaska                          18
# Cobalt                               18
# Skymark Airlines                     17
# Nouvelair                            17
# FLYONE                               16
# Amaszonas                            16
# euroAtlantic Airways                 16
# Nature Air                           16
# Libyan Airlines                      16
# Air Greenland                        16
# Air Bagan                            16
# T'Way Air                            15
# Wamos Air                            15
# Seaborne Airlines                    15
# Tianjin Airlines                     15
# Ellinair                             14
# Binter Canarias                      14
# LC Perú                              14
# Aigle Azur                           14
# Air Panama                           14
# Air Cairo                            14
# Buddha Air                           14
# NAM Air                              13
# Vanilla Air                          13
# SmartLynx Airlines                   13
# TAG Airlines                         13
# Privilege Style                      13
# Mokulele Airlines                    13
# HOP!                                 13
# Pacific Airlines                     13
# Malawian Airlines                    12
# Berjaya Air                          12
# Tame Línea Aérea Del Ecuador         12
# Salam Air                            12
# Shaheen Air                          12
# SereneAir                            12
# ViaAir                               11
# Myanmar National Airlines            11
# Cyprus Airways                       11
# Central Mountain Air                 11
# Omni Air International               11
# Aerosur                              11
# Joon                                 11
# Safi Airways                         10
# Utair Aviation                       10
# Carpatair                            10
# Solomon Airlines                     10
# Air Corsica                          10
# Atlantic Airways                     10
# JetSmart                             10
# Avior Airlines                        9
# Aeromar                               9
# Buta Airways                          9
# Thomas Cook Airlines Scandinavia      9
# Air KBZ                               9
# PAL Express                           9
# Africa World Airlines                 9
# Bassaka Air                           9
# TAR Aerolineas                        9
# InterSky                              8
# Tigerair Taiwan                       8
# Intercaribbean Airways                8
# LAN Colombia                          8
# Dniproavia                            8
# TransAsia Airways                     7
# V Air                                 7
# Easyfly                               7
# Canadian North                        7
# Super Air Jet                         7
# Lucky Air                             7
# Primera Air                           7
# FlyArystan                            7
# Winair                                7
# Bluebird Airways                      7
# US-Bangla Airlines                    6
# Evelop Airlines                       6
# Bhutan Airlines                       6
# StarFlyer                             6
# Mihin Lanka                           6
# Eritrean Airlines                     6
# Canaryfly                             6
# Uganda Airlines                       5
# Conviasa                              5
# Tropic Air Belize                     5
# Yeti Airlines                         5
# Air Mediterranee                      5
# Beijing Capital Airlines              5
# Alliance Airlines                     5
# China United Airlines                 5
# Moldavian Airlines                    5
# Jazz                                  5
# SCAT Airlines                         4
# Air North Yukon's Airline             4
# flybe                                 4
# Mandarin Airlines                     4
# Greater Bay Airlines                  4
# Maldivian                             4
# Air Antilles                          4
# UP by El Al                           4
# Red Wings Airlines                    4
# HiSky                                 4
# Iraqi Airways                         4
# Okay Airways                          4
# Ernest Airlines                       4
# AirSWIFT                              4
# Sansa Airlines                        4
# Nordavia                              4
# Yangon Airways                        4
# Coastal Aviation                      4
# Andes Líneas Aéreas                   4
# Air Pegasus                           4
# Yakutia Airlines                      4
# Tailwind Airlines                     3
# Motor Sich Airlines                   3
# Passion Air                           3
# Ultra Air                             3
# TACA Regional                         3
# Air Iceland Connect                   3
# PenAir                                3
# Golden Myanmar Airlines               3
# AB Aviation                           3
# Petroleum Air Services                3
# World2Fly                             3
# Nordica                               3
# Aero VIP                              3
# Eastern Airlines                      3
# Somon Air                             3
# Smartavia                             3
# CemAir                                3
# SkyUp Airlines                        3
# Aerocaribbean                         3
# Skybus                                3
# Loch Lomond Seaplanes                 2
# NokScoot                              2
# Air Rarotonga                         2
# Trigana Air                           2
# Lubeck Air                            2
# Nauru Airlines                        2
# TUS Airways                           2
# Maya Island Air                       2
# Kan Air                               2
# Jordan Aviation                       2
# Air Malawi                            2
# Madagasikara Airways                  2
# Air Burkina                           2
# Mann Yadanarpon Airlines              2
# Air Djibouti                          2
# Mauritania Airlines                   2
# Nordwind Airlines                     2
# Sun-Air                               2
# Novoair                               2
# Felix Airways                         2
# Camair-Co                             2
# Cambodia Airways                      2
# Qazaq Air                             2
# PAWA Dominicana                       2
# SkyWork Airlines                      2
# Azur Air Germany                      2
# Skytrans Airlines                     2
# FMI Air                               2
# ATA Airlines                          2
# SATENA                                2
# Safarilink                            2
# Armenia Air Company                   2
# AeroItalia                            1
# Sol Líneas Aéreas                     1
# Air Costa                             1
# Manta Air                             1
# Zambia Airways                        1
# Dynamic International Airways         1
# Voyage Air                            1
# JetsuiteX                             1
# KD Air                                1
# Cambodia Bayon Airlines               1
# Mack Air                              1
# Eswatini Air                          1
# Air Cote d'Ivoire                     1
# Rhein-Neckar Air                      1
# Europe Airpost                        1
# EWA Air                               1
# NordStar                              1
# BoraJet                               1
# Himalaya Airlines                     1
# Nordic Regional Airlines              1
# Hunnu Air                             1
# Novair                                1
# Ariana Afghan Airlines                1
# TransNusa                             1
# Iberojet                              1
# Nile Air                              1
# TUIfly Nordic                         1
# Auric Air                             1
# NextJet                               1
# Henan Airlines                        1
# Sudan Airways                         1
# Badr Airlines                         1
# Pan Pacific Airlines                  1
# SVG Air                               1
# Air Labrador                          1
# Grand Cru Airlines                    1
# Suparna Airlines                      1
# JC International Airlines             1
# MEGA Maldives Airlines                1
# MAYAir                                1
# Tibet Airlines                        1
# Dimonim Air                           1
# Name: count, dtype: int64

# %% [markdown]
# # Overall Analysis

# %% [markdown]
# ##  Average of Overall_Rating

# %%
# Converting the data type to numeric
airlines_df['Overall_Rating'] = pd.to_numeric(airlines_df['Overall_Rating'], errors='coerce')
# Taking the median as average rating
avg_ratings = airlines_df.groupby('Airline Name')['Overall_Rating'].median().round(2)
avg_ratings
# Out:
# Airline Name
# AB Aviation                         1.0
# ANA All Nippon Airways              1.5
# ASKY Airlines                       1.0
# ATA Airlines                        1.5
# Adria Airways                       5.0
# Aegean Airlines                     1.5
# Aer Lingus                          1.0
# Aero VIP                            9.0
# AeroItalia                          2.0
# Aerocaribbean                       1.0
# Aeroflot Russian Airlines           1.0
# Aerolineas Argentinas               3.0
# Aeromar                             1.0
# Aeromexico                          1.0
# Aerosur                             5.0
# Africa World Airlines               1.0
# Afriqiyah Airways                   4.0
# Aigle Azur                          1.0
# Air Algerie                         2.0
# Air Antilles                        1.0
# Air Arabia                          1.0
# Air Astana                          1.0
# Air Austral                         5.0
# Air Bagan                           5.0
# Air Berlin                          2.0
# Air Botswana                        4.0
# Air Burkina                         5.5
# Air Busan                           1.0
# Air Cairo                           1.0
# Air Canada                          1.0
# Air Canada rouge                    1.0
# Air Caraibes                        2.0
# Air China                           2.0
# Air Corsica                         3.0
# Air Costa                           8.0
# Air Cote d'Ivoire                   1.0
# Air Djibouti                        6.5
# Air Dolomiti                        5.0
# Air Europa                          1.0
# Air France                          2.0
# Air Greenland                       1.0
# Air Iceland Connect                 1.0
# Air India                           1.0
# Air India Express                   2.0
# Air Italy                           2.0
# Air Juan                            1.0
# Air KBZ                             8.0
# Air Koryo                           6.0
# Air Labrador                        2.0
# Air Macau                           4.0
# Air Madagascar                      1.0
# Air Malawi                          3.5
# Air Malta                           1.0
# Air Mauritius                       4.0
# Air Mediterranee                    4.0
# Air Memphis                         1.5
# Air Moldova                         2.5
# Air Namibia                         4.0
# Air New Zealand                     1.0
# Air Niugini                         2.0
# Air North Yukon's Airline           5.0
# Air Nostrum                         4.5
# Air Panama                          1.0
# Air Pegasus                         3.5
# Air Rarotonga                       1.0
# Air Serbia                          1.0
# Air Seychelles                      2.0
# Air Tahiti Nui                      2.0
# Air Tanzania                        1.0
# Air Transat                         1.0
# Air Zimbabwe                        1.0
# AirAsia                             1.0
# AirAsia India                       1.0
# AirAsia Philippines                 1.0
# AirAsia X                           3.0
# AirAsia Zest                        3.0
# AirSWIFT                            1.0
# Aircalin                            4.0
# Airlink                             1.0
# Airnorth                            5.5
# Akasa Air                           1.0
# Alaska Airlines                     1.0
# Alitalia                            1.0
# Allegiant Air                       1.0
# Alliance Air                        1.0
# Alliance Airlines                   1.0
# Amaszonas                           2.0
# American Airlines                   1.0
# American Eagle                      2.0
# AnadoluJet                          3.5
# Andes Líneas Aéreas                 1.0
# Ariana Afghan Airlines              6.0
# Arik Air                            1.0
# Arkefly                             2.0
# Armenia Air Company                 1.0
# Asiana Airlines                     4.0
# Atlantic Airways                    8.0
# Auric Air                           1.0
# Aurigny Air                         3.0
# Austrian Airlines                   1.0
# Avelo Airlines                      1.0
# Avianca                             1.0
# Avior Airlines                      3.0
# Azerbaijan Airlines                 4.0
# Azur Air Germany                    1.0
# BA CityFlyer                        6.0
# Badr Airlines                       8.0
# Bahamasair                          1.0
# Bamboo Airways                      1.0
# Bangkok Airways                     4.0
# Bassaka Air                         1.0
# Batik Air                           2.0
# Beijing Capital Airlines            5.0
# Belavia                             5.0
# Berjaya Air                         8.0
# Bhutan Airlines                     1.0
# Binter Canarias                     1.0
# Blue Air                            1.0
# Blue Islands                        2.0
# Blue Panorama Airlines              1.0
# Blue1                               5.0
# Bluebird Airways                    1.0
# BoraJet                             1.0
# Boutique Air                        1.0
# Breeze Airways                      1.0
# British Airways                     1.0
# Brussels Airlines                   1.0
# Buddha Air                          3.0
# Bulgaria Air                        7.0
# Buta Airways                        1.0
# CSA Czech Airlines                  2.0
# Camair-Co                           1.0
# Cambodia Airways                    4.0
# Cambodia Bayon Airlines             3.0
# Canadian North                      6.0
# Canaryfly                           5.0
# Cape Air                            1.0
# Caribbean Airlines                  2.0
# Carpatair                           4.0
# Cathay Dragon                       7.0
# Cathay Pacific Airways              3.0
# Cayman Airways                      2.0
# Cebu Pacific                        1.0
# CemAir                              1.0
# Central Mountain Air                3.0
# China Airlines                      5.0
# China Eastern Airlines              2.0
# China Southern Airlines             8.0
# China United Airlines               4.0
# Citilink                            7.0
# CityJet                             2.0
# Coastal Aviation                    3.0
# Cobalt                              5.5
# Comair                              6.0
# Condor Airlines                     1.0
# Conviasa                            8.0
# Copa Airlines                       1.0
# Corendon Airlines                   1.0
# Corsair                             4.0
# Croatia Airlines                    5.0
# Cubana Airlines                     3.0
# Cyprus Airways                      1.0
# Delta Air Lines                     1.0
# Dimonim Air                         7.0
# Dniproavia                          7.0
# Dragonair                           7.0
# Druk Air                            7.0
# Dynamic International Airways       1.0
# EVA Air                             3.0
# EWA Air                             1.0
# Eastern Airlines                    1.0
# Eastern Airways                     2.0
# Easyfly                             8.0
# Edelweiss Air                       2.0
# Egyptair                            1.0
# El Al Israel Airlines               1.0
# Ellinair                            4.5
# Emirates                            2.0
# Eritrean Airlines                   6.0
# Ernest Airlines                     1.0
# Estonian Air                        3.5
# Eswatini Air                        9.0
# Ethiopian Airlines                  2.0
# Etihad Airways                      1.0
# Europe Airpost                      9.0
# Eurowings                           1.0
# Evelop Airlines                     2.0
# FLYONE                              1.0
# FMI Air                             1.0
# Felix Airways                       7.5
# Fiji Airways                        2.0
# Finnair                             1.0
# Firefly                             5.0
# Flair Airlines                      1.0
# Fly540.com                          4.0
# FlyArystan                          8.0
# FlySafair                           1.0
# Flynas                              1.0
# French Bee                          1.0
# Frontier Airlines                   1.0
# Garuda Indonesia                    1.0
# Georgian Airways                    1.0
# Germania Airline                    6.0
# Germanwings                         4.0
# Go First                            1.0
# GoAir                               1.0
# Golden Myanmar Airlines             8.0
# Grand Cru Airlines                  1.0
# Greater Bay Airlines                2.5
# Gulf Air                            2.0
# HOP!                                7.0
# Hainan Airlines                     1.0
# Hawaiian Airlines                   1.0
# Henan Airlines                      8.0
# Hi Fly                              2.0
# HiSky                               5.0
# Himalaya Airlines                   1.0
# Hong Kong Airlines                  5.0
# Horizon Air                         4.5
# Hunnu Air                           9.0
# ITA Airways                         1.0
# Iberia                              1.5
# Iberia Express                      2.0
# Iberojet                            1.0
# Icelandair                          1.0
# Insel Air                           1.0
# InterSky                            4.0
# Intercaribbean Airways              1.0
# Interjet                            1.0
# Iran Air                            3.5
# Iraqi Airways                       4.5
# Israir Airlines                     1.0
# JC International Airlines           1.0
# Japan Airlines                      2.0
# Jazeera Airways                     1.0
# Jazz                                8.0
# Jeju Air                            2.0
# Jet Airways                         1.0
# Jet2.com                            1.0
# JetSmart                            1.0
# Jetairfly                           4.0
# Jetblue Airways                     1.0
# Jetstar Airways                     1.0
# Jetstar Asia                        1.0
# Jetstar Japan                       1.0
# Jetstar Pacific                     1.0
# JetsuiteX                           1.0
# Jin Air                             5.5
# Joon                                3.0
# Jordan Aviation                     5.0
# KD Air                              1.0
# KLM Royal Dutch Airlines            1.0
# Kam Air                             3.0
# Kan Air                             1.0
# Karthago Airlines                   1.0
# Kenya Airways                       1.0
# Korean Air                          4.0
# Kulula                              2.0
# Kuwait Airways                      1.0
# LAN Airlines                        3.5
# LAN Colombia                        2.5
# LAN Peru                            3.0
# LATAM Airlines                      1.0
# LC Perú                             1.0
# LIAT                                1.0
# LOT Polish Airlines                 1.0
# La Compagnie                        3.0
# Lao Airlines                        7.0
# Laudamotion                         1.0
# Level                               1.0
# Libyan Airlines                     3.0
# Lion Air                            1.0
# Loch Lomond Seaplanes               3.0
# Loganair                            1.0
# Lubeck Air                          1.0
# Lucky Air                           4.0
# Lufthansa                           2.0
# Luxair                              5.0
# Lynx Air                            1.0
# MAYAir                              1.0
# MEGA Maldives Airlines              4.0
# Mack Air                            9.0
# Madagasikara Airways                1.0
# Mahan Air                           8.0
# Malawian Airlines                   2.0
# Malaysia Airlines                   2.0
# Maldivian                           6.0
# Malindo Air                         1.0
# Mandarin Airlines                   7.5
# Mann Yadanarpon Airlines            8.0
# Manta Air                           9.0
# Martinair                           3.0
# Mauritania Airlines                 3.0
# Maya Island Air                     1.0
# Meridiana                           3.0
# Mihin Lanka                         5.5
# Mokulele Airlines                   2.0
# Moldavian Airlines                  8.5
# Monarch Airlines                    3.0
# Montenegro Airlines                 4.0
# Motor Sich Airlines                 1.0
# Myanmar Airways                     7.5
# Myanmar National Airlines           1.0
# NAM Air                             4.0
# NIKI                                3.0
# Nature Air                          1.0
# Nauru Airlines                      9.0
# Nepal Airlines                      7.0
# NextJet                             3.0
# Nile Air                            8.0
# Nok Air                             1.0
# NokScoot                            4.5
# NordStar                            7.0
# Nordavia                            1.0
# Nordic Regional Airlines            6.0
# Nordica                             1.0
# Nordwind Airlines                   4.0
# Norse Atlantic Airways              1.0
# Norwegian                           1.0
# Nouvelair                           1.0
# Novair                              7.0
# Novoair                             4.0
# Okay Airways                        6.5
# Olympic Air                         5.0
# Oman Air                            1.0
# Omni Air International              2.0
# Onur Air                            3.0
# Openskies                           3.0
# PAL Express                         2.0
# PAWA Dominicana                     4.5
# PLAY                                3.0
# Pacific Airlines                    2.0
# Pan Pacific Airlines                1.0
# Passion Air                         2.0
# Peach Aviation                      1.0
# Pegasus Airlines                    1.0
# PenAir                              2.0
# Peruvian Airlines                   1.0
# Petroleum Air Services              1.0
# Philippine Airlines                 2.0
# Phuket Air                          1.0
# Pobeda Airlines                     1.0
# Porter Airlines                     1.0
# Primera Air                         1.0
# Privilege Style                     2.0
# Qantas Airways                      1.0
# QantasLink                          8.0
# Qatar Airways                       3.0
# Qazaq Air                           9.0
# Ravn Alaska                         2.0
# Red Wings Airlines                  1.0
# Regent Airways                      4.0
# Regional Express                    2.0
# Rex Airlines                        1.0
# Rhein-Neckar Air                    1.0
# Rossiya Airlines                    6.0
# Royal Air Maroc                     1.0
# Royal Brunei Airlines               6.5
# Royal Jordanian Airlines            1.0
# Rwandair                            3.0
# Ryanair                             1.0
# S7 Siberia Airlines                 5.0
# SA Express                          2.0
# SATA Air Azores                     1.0
# SATENA                              5.0
# SCAT Airlines                       8.0
# SVG Air                             6.0
# Safarilink                          8.0
# Safi Airways                        4.5
# Salam Air                           1.0
# Sansa Airlines                      1.0
# Saudi Arabian Airlines              1.5
# Scoot                               1.0
# Seaborne Airlines                   1.0
# SereneAir                           1.0
# Shaheen Air                         7.5
# Shandong Airlines                   4.0
# Shanghai Airlines                   4.0
# Shenzhen Airlines                   4.0
# Sichuan Airlines                    4.0
# SilkAir                             5.0
# Silver Airways                      1.0
# Singapore Airlines                  4.0
# Sky Airline                         1.0
# Sky Express Airlines                1.0
# SkyUp Airlines                      1.0
# SkyWest Airlines                    7.0
# SkyWork Airlines                    4.5
# Skybus                              3.0
# Skymark Airlines                    7.0
# Skytrans Airlines                   4.5
# SmartLynx Airlines                  1.0
# SmartWings                          2.0
# Smartavia                           1.0
# Sol Líneas Aéreas                   1.0
# Solomon Airlines                    6.0
# Somon Air                           5.0
# South African Airways               2.5
# Southwest Airlines                  1.0
# SpiceJet                            1.0
# Spirit Airlines                     1.0
# SriLankan Airlines                  1.0
# Sriwijaya Air                       2.5
# StarFlyer                           1.0
# Sudan Airways                       1.0
# Sun Country Airlines                1.0
# Sun-Air                             1.0
# Sunwing Airlines                    1.0
# Suparna Airlines                    5.0
# Super Air Jet                       1.0
# Surinam Airways                     3.0
# Swoop                               1.0
# SyrianAir                           2.0
# T'Way Air                           1.0
# TAAG Angola Airlines                3.0
# TACA Regional                       1.0
# TAG Airlines                        1.0
# TAM Airlines                        4.0
# TAME                                1.0
# TAP Portugal                        1.0
# TAR Aerolineas                      1.0
# TUI Airways                         2.0
# TUIfly                              4.0
# TUIfly Nordic                       5.0
# TUS Airways                         5.0
# Tailwind Airlines                   6.0
# Tame Línea Aérea Del Ecuador        1.0
# Thai AirAsia                        2.0
# Thai Airways                        3.0
# Thai Lion Air                       1.0
# Thai Smile Airways                  3.0
# Thomas Cook Airlines                2.0
# Thomas Cook Airlines Scandinavia    5.0
# Thomson Airways                     4.5
# Tianjin Airlines                    8.0
# Tibet Airlines                      8.0
# Tigerair                            4.0
# Tigerair Australia                  1.0
# Tigerair Taiwan                     1.5
# Titan Airways                       1.0
# TransAsia Airways                   9.0
# TransNusa                           5.0
# Transaero Airlines                  5.0
# Transavia                           1.0
# Trigana Air                         7.5
# Tropic Air Belize                   7.0
# Tunisair                            4.0
# Turkish Airlines                    1.0
# Turkmenistan Airlines               4.0
# UP by El Al                         3.0
# US Airways                          1.0
# US-Bangla Airlines                  4.0
# Uganda Airlines                     3.0
# Ultra Air                           1.0
# United Airlines                     1.0
# Ural Airlines                       3.0
# Utair Aviation                      7.0
# Uzbekistan Airways                  4.0
# V Air                               2.0
# VLM Airlines                        5.0
# Vanilla Air                         2.0
# ViaAir                              1.0
# Vietnam Airlines                    3.0
# Virgin America                      2.0
# Virgin Australia                    5.0
# Vistara                             2.0
# Viva Air                            1.0
# VivaAerobús                         1.0
# VivaColombia                        1.0
# Volaris                             1.0
# Volotea                             1.0
# Voyage Air                          1.0
# Vueling Airlines                    1.0
# WOW air                             1.0
# Wamos Air                           2.0
# Wideroe                             1.0
# Winair                              1.0
# Wingo                               1.0
# Wings Air                           1.0
# Wizz Air                            1.0
# World2Fly                           1.0
# XL Airways France                   2.0
# Xiamen Airlines                     4.0
# Yakutia Airlines                    6.0
# Yangon Airways                      7.5
# Yemenia                             5.0
# Yeti Airlines                       2.0
# ZIPAIR                              1.0
# Zambia Airways                      7.0
# airBaltic                           1.0
# bmi Regional                        1.0
# easyJet                             1.0
# euroAtlantic Airways                1.0
# fastjet                             1.0
# flyadeal                            1.0
# flybe                               1.0
# flydubai                            1.0
# Name: Overall_Rating, dtype: float64

# %% [markdown]
# ## Top Airlines by Number of Reviews and average Rating

# %%
# Grouping by airline and calculating the number of reviews and average rating
airline_stats = airlines_df.groupby('Airline Name').agg({
    'Overall_Rating': ['count', 'median']
}).reset_index()

# Renaming the columns
airline_stats.columns = ['Airline Name', 'Review Count', 'Average Rating']

# Filtering: only airlines with at least 50 reviews
filtered = airline_stats[airline_stats['Review Count'] >= 50]

# Sorting by average rating and getting the top 10
top10_airlines = filtered.sort_values(by='Average Rating', ascending=False).head(10)

# Plot: combining the both metrics
fig, ax1 = plt.subplots(figsize=(14, 8))

# Barplot for number of reviews
sns.barplot(data=top10_airlines, x='Airline Name', y='Review Count', color='cornflowerblue', ax=ax1)
ax1.set_ylabel('Number of Reviews', color='cornflowerblue', fontsize=17)
ax1.tick_params(axis='y', labelcolor='cornflowerblue')
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=60, ha='right', fontsize=14)

# Line plot for average rating
ax2 = ax1.twinx()
sns.lineplot(data=top10_airlines, x='Airline Name', y='Average Rating', color='darkgreen', marker='o', ax=ax2)
ax1.set_xlabel(' ', color='darkgreen', fontsize= 17)
ax2.set_ylabel('Average Rating', color='darkgreen', fontsize= 17)
ax2.tick_params(axis='y', labelcolor='darkgreen')
ax1.set_yticklabels(ax1.get_yticklabels(), fontsize=12)
ax2.set_yticklabels(ax1.get_yticklabels(), fontsize=12)
ax2.set_ylim(0, 10)

plt.title('QantasLink and China Southern Airlines have the Highest Ratings', fontsize=20, color='darkslategray', fontweight= 'bold')
plt.tight_layout(pad=2)
plt.show()

# %% [markdown]
# ## Average Rating by Seat Type

# %%
# Grouping by seat type and calculating the average rating
avg_rating_by_seat = airlines_df.groupby('Seat Type')['Overall_Rating'].median().reset_index()

# Sorting the values descending
avg_rating_by_seat = avg_rating_by_seat.sort_values(by='Overall_Rating', ascending=False)

# Plot
plt.figure(figsize=(8, 5))
sns.barplot(data=avg_rating_by_seat, x='Seat Type', y='Overall_Rating', palette='Blues_d')
plt.title('Median Rating by Seat Type', fontsize=25)
plt.xlabel('Seat Type', fontsize=17)
plt.ylabel('Median Rating', fontsize=17)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#Checking the number of reviews for each seat type
num_of_ratings = airlines_df['Seat Type'].value_counts()
num_of_ratings

# %%
# Calculating average rating per seat type
seat_order = airlines_df.groupby('Seat Type')['Overall_Rating'].median().sort_values(ascending=False).index

# Plotting the sorted boxplot
plt.figure(figsize=(10, 7))
sns.boxplot(data=airlines_df, x='Overall_Rating', y='Seat Type', palette='viridis', order=seat_order)
plt.title('Business and First Class Passengers Gave Higher Ratings', fontsize=25, fontweight='bold', color='darkslategray')
plt.xlabel('Average Rating', fontsize=20)
plt.ylabel('Seat Type', fontsize=20)
plt.xticks(fontsize=17)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Correlation between Overall Rating and Rating Categories

# %%
# Choosing the columns to do the correlation test
corr_categories = airlines_df[['Overall_Rating', 'Value For Money', 'Ground Service',
                              'Food & Beverages', 'Cabin Staff Service', 'Seat Comfort']].corr()

# Extracting and sorting the correlations with rating (excluding rating itself)
correlations_with_rating = corr_categories['Overall_Rating'].drop('Overall_Rating').sort_values(ascending=True)
# plotting
plt.figure(figsize=(8, 5))
correlations_with_rating.plot(kind='barh', color='cornflowerblue')
plt.title('Value for Money Affects the Most on the Average Rating', fontsize=20, fontweight='bold', color='darkslategray')
plt.xlabel('Correlation efficiency', fontsize=17)
plt.tick_params(axis='x', labelsize=14)
plt.tick_params(axis='y', labelsize=14) 
plt.grid(True, axis='x', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Average Rating by Type of Traveller

# %%
# Taking the avrage rating
traveller_avg_rating = airlines_df.groupby('Type Of Traveller')['Overall_Rating'].median().reset_index()

# Sorting the values
traveller_avg_rating = traveller_avg_rating.sort_values(by='Overall_Rating', ascending=True)

# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(data=traveller_avg_rating, x='Overall_Rating', y='Type Of Traveller', palette='viridis')

plt.title('Average Overall Rating by Type of Traveller', fontsize = 27)
plt.xlabel('Average Rating', fontsize = 17)
plt.ylabel('Type of Traveller', fontsize = 17)
plt.xlim(0, 5)  # Assuming rating scale is from 0 to 5
plt.grid(True, axis='x', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
# Checking the number of reviews in traveller type
num_of_traveller_type = airlines_df['Type Of Traveller'].value_counts()
num_of_traveller_type

# %%
 # Taking the average of Overall Rating and sorting by descending
traveller_order = airlines_df.groupby('Type Of Traveller')['Overall_Rating'].median().sort_values(ascending=False).index

# Plotting boxplot 
plt.figure(figsize=(10, 6))
sns.boxplot(data=airlines_df, x='Overall_Rating', y='Type Of Traveller', palette='viridis', order=traveller_order)

plt.title('Solo and Business Travellers Gave Higher Ratings', fontsize=27, fontweight='bold', color='darkslategray')
plt.xlabel('Overall Rating', fontsize=20)
plt.ylabel('Type of Traveller', fontsize=20)
plt.xticks(fontsize=17)
plt.yticks(fontsize=15)
plt.xlim(0, 10) 
plt.grid(True, axis='x', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Overall Rating vs Recommendation

# %%
# Taking the average
recommended_rating = airlines_df.groupby('Recommended')['Overall_Rating'].median().reset_index()
# Sorting the values
recommended_rating = recommended_rating.sort_values(by='Overall_Rating', ascending=False)

# Plotting
plt.figure(figsize=(8, 6))
sns.barplot(data=recommended_rating, x='Recommended', y='Overall_Rating', palette='muted')

plt.title('Higher Rating = Recommended', fontsize=27, fontweight='bold', color='darkslategray')
plt.xlabel('Recommendation', fontsize=17)
plt.ylabel('Average Rating', fontsize=17)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.ylim(0, 10)  
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Time Based Analysis

# %%
# Removng ordinal suffixes and creating a new cleaned column
airlines_df['Cleaned Review Date'] = airlines_df['Review Date'].str.replace(
    r'(\d{1,2})(st|nd|rd|th)', r'\1', regex=True)

# Converting the cleaned text to datetime format
airlines_df['Cleaned Review Date'] = pd.to_datetime(
    airlines_df['Cleaned Review Date'], format='%d %B %Y')
airlines_df

# %%
#Saving the csv file
airlines_df.to_csv("airlines_cleaned.csv", index=False)

# %% [markdown]
# # Text and Sentiment Analysis

# %% [markdown]
# # Cleaning the Text

# %%
# Installing the library to clean the written text
# !pip install nltk

# %%
# importing all the libraries for text analysis
import nltk
import string
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from collections import Counter

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

# %%
# Choosing the languages English
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# Cleaning the text
def clean_text(text):
    if pd.isnull(text): return ""
    text = text.lower()
    tokens = nltk.word_tokenize(text)
    tokens = [word for word in tokens if word.isalpha() and word not in stop_words]
    tokens = [lemmatizer.lemmatize(word) for word in tokens]
    return ' '.join(tokens)
# Creating new and cleaned columns   
airlines_df['clean_title'] = airlines_df['Review_Title'].apply(clean_text)
airlines_df['clean_review'] = airlines_df['Review'].apply(clean_text)

# %% [markdown]
# # Sentiment Analysis

# %%
# Intalling the model for sentiment analysis
! pip install vaderSentiment

# %%
# Importing the classifier
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# giving it a simple name
analyzer = SentimentIntensityAnalyzer()

# counting the polarity score
def get_sentiment_scores(text):
    if pd.isnull(text):
        return {'neg': 0, 'neu': 0, 'pos': 0, 'compound': 0}
    return analyzer.polarity_scores(text)


# Applying it to cleaned review column
review_scores = airlines_df['clean_review'].apply(get_sentiment_scores).apply(pd.Series)
review_scores.columns = ['review_negative', 'review_neutral', 'review_positive', 'review_compound']

# Combining
airlines_df = pd.concat([airlines_df, review_scores], axis=1)

# %%
# Converting to numeric (In case)
airlines_df['review_compound'] = pd.to_numeric(airlines_df['review_compound'], errors='coerce')

# Defining sentiment classification
def classify_sentiment(score):
    if pd.isnull(score):
        return 'unknown'
    elif score >= 0.05:
        return 'positive'
    elif score <= -0.05:
        return 'negative'
    else:
        return 'neutral'

# Applying the classification
airlines_df['review_sentiment'] = airlines_df['review_compound'].apply(classify_sentiment)

# %%
airlines_df

# %%
# Checking the count
reviews_sent= airlines_df['review_sentiment'].value_counts()
reviews_sent

# %%
# Defining custom colors for each sentiment
custom_palette = {
    'positive': 'seagreen',
    'negative': 'firebrick',
    'neutral': 'gold'
}

# Sorting the order by value count
order = airlines_df['review_sentiment'].value_counts().index

# Plotting
plt.figure(figsize=(8, 5))
sns.countplot(data=airlines_df, x='review_sentiment', order=order, palette=custom_palette)
plt.title('Positives are More Than the Negatives', fontsize=18, fontweight='bold', color='darkslategray')
plt.xlabel(' ', fontsize=14)
plt.ylabel('Count', fontsize=17)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Text Analysis

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Trigram Extraction
vectorizer = CountVectorizer(ngram_range=(3, 3), max_features=10)
X2 = vectorizer.fit_transform(airlines_df['clean_review'])

# Getting the top trigrams
trigrams = vectorizer.get_feature_names_out()
counts = X2.sum(axis=0).A1
trigram_freq = pd.DataFrame({'Trigram': trigrams, 'Count': counts}).sort_values(by='Count', ascending=False)
trigram_freq.rename(columns={'Trigram': ''}, inplace=True)

# Creating color list based on negatives
highlight_indices = [0, 1, 5, 6, 7]  # 0-based indexing
colors = ['firebrick' if i in highlight_indices else 'cornflowerblue' for i in range(len(trigram_freq))]

# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(data=trigram_freq, x='Count', y='', palette=colors)
plt.title('Negativity Detected', fontsize=27, fontweight='bold', color='firebrick')
plt.xlabel('Count', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
#filtering the positive and negative reviews
positive_reviews = airlines_df[airlines_df['review_sentiment'] == 'positive']['Review']
negative_reviews = airlines_df[airlines_df['review_sentiment'] == 'negative']['Review']

# %%
positive_text = " ".join(positive_reviews.astype(str))
negative_text = " ".join(negative_reviews.astype(str))

# %%
from wordcloud import STOPWORDS

# Setting default stopwords
custom_stopwords = set(STOPWORDS)

# Adding stopwords manually
custom_stopwords.update([
    'flight', 'flights', 'airport' , 'airline', 'plane', 'air', 'seat', 'fly', 'travel', 'passenger','even'  # common airline words
    'get', 'got', 'make', 'just', 'one', 'like', 'really', 'still', 'will'  # generic filler words
])

# %%
# Using the library to choose bigrams and filtering postive reviews
vectorizer_pos = CountVectorizer(ngram_range=(2, 2), stop_words=list(custom_stopwords))
X_pos = vectorizer_pos.fit_transform([positive_text])

# Creating frequency dictionary
bigrams_freq_pos = dict(zip(vectorizer_pos.get_feature_names_out(), X_pos.toarray().sum(axis=0)))

# Generating word cloud
wordcloud_positive_bigram = WordCloud(
    width=800, height=400, background_color='white', colormap='Greens'
).generate_from_frequencies(bigrams_freq_pos)

# Plotting
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_positive_bigram, interpolation='bilinear')
plt.axis('off')
plt.title(' ', fontsize=18, fontweight='bold', color='green')
plt.tight_layout()
plt.show()

# %%
# Using the library to choose bigrams and filtering negative reviews
vectorizer_neg = CountVectorizer(ngram_range=(2, 2), stop_words=list(custom_stopwords))
X_neg = vectorizer_neg.fit_transform([negative_text])

# Creating frequency dictionary
bigrams_freq_neg = dict(zip(vectorizer_neg.get_feature_names_out(), X_neg.toarray().sum(axis=0)))

# Generating word cloud
wordcloud_negative_bigram = WordCloud(
    width=800, height=400, background_color='white', colormap='Reds'
).generate_from_frequencies(bigrams_freq_neg)

#  Plotting
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_negative_bigram, interpolation='bilinear')
plt.axis('off')
plt.title(' ', fontsize=18, fontweight='bold', color='red')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Arab Airlines Analysis

# %% [markdown]
# ## Filtering the data to Arab Airlines Only

# %%
# List of airlines to filter
target_airlines = [
    'Air Arabia',
    'Emirates',
    'Etihad Airways',
    'Gulf Air',
    'Qatar Airways',
    'Saudi Arabian Airlines'
]

# Filtering the DataFrame
filtered_df = airlines_df[airlines_df['Airline Name'].isin(target_airlines)]
filtered_df

# %%
# Calculating the Average Rating per airline
median_ratings = filtered_df.groupby('Airline Name')['Overall_Rating'].mean().reset_index()

# Sorting by rating descending
median_ratings = median_ratings.sort_values(by='Overall_Rating', ascending=False).reset_index(drop=True)

# Defining colors 
colors = ['cornflowerblue'] * len(median_ratings)
colors[0] = 'tomato'  
colors[1] = 'darkorange'   

# Plotting
plt.figure(figsize=(10, 8))
sns.barplot(data=median_ratings, y='Airline Name', x='Overall_Rating', palette=colors)

plt.xlabel('Average Rating', color='black', fontsize=14)
plt.ylabel(' ', fontsize=14)
plt.title('Qatar and Gulf Air Have the Highest Ratings', fontsize=20, fontweight='bold', color='darkslategray')
plt.xlim(0, 10)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout(pad=2)
plt.grid(True, axis='x', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ## Repeating the wordcloud steps to generate positive and Negative wordcloud for GCC Airlines

# %%
positive_reviewss = filtered_df[filtered_df['review_sentiment'] == 'positive']['Review']
negative_reviewss = filtered_df[filtered_df['review_sentiment'] == 'negative']['Review']

# %%
filtered_positive_text = " ".join(positive_reviewss.astype(str))
filtered_negative_text = " ".join(negative_reviewss.astype(str))

# %%
# For positive reviews
wordcloud_positive_filtered = WordCloud(width=800, height=400, background_color='white', colormap='Greens', stopwords=custom_stopwords).generate(filtered_positive_text)

# For negative reviews
wordcloud_negative_filtered = WordCloud(width=800, height=400, background_color='white', colormap='Reds', stopwords=custom_stopwords).generate(filtered_negative_text)

# %%
#Positive
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_positive_filtered, interpolation='bilinear')
plt.axis('off')
plt.title('Positive Reviews Word Cloud')
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_negative_filtered, interpolation='bilinear')
plt.axis('off')
plt.title('Negative Reviews Word Cloud')
plt.show()

# %% [markdown]
# # Gulf Air Analysis

# %%
# Selecting the Gulf Air
targett_airlines = ['Gulf Air']

# Filtering the DataFrame
gulf_df = airlines_df[airlines_df['Airline Name'].isin(targett_airlines)]
gulf_df

# %%
# Counting the sentiment values
sentiment_counts = gulf_df['review_sentiment'].value_counts()

# Plotting
plt.figure(figsize=(6, 4))
sentiment_counts[['positive', 'negative']].plot(kind='bar', color=['forestgreen', 'firebrick'])

plt.title('Almost Equal', fontsize=20, fontweight='bold', color='darkslategray')
plt.xlabel(' ')
plt.ylabel('Number of Reviews', fontsize='17')
plt.xticks(rotation =0, fontsize=17)
plt.yticks(fontsize=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Repeating the wordcloud steps to generate positive and Negative wordcloud for Gulf Air Reviews

# %%
gulf_positive_reviews = gulf_df[gulf_df['review_sentiment'] == 'positive']['Review']
gulf_negative_reviews = gulf_df[gulf_df['review_sentiment'] == 'negative']['Review']

# %%
gulf_positive_text = " ".join(gulf_positive_reviews.astype(str))
gulf_negative_text = " ".join(gulf_negative_reviews.astype(str))

# %%
# For positive reviews
wordcloud_positive_filtered = WordCloud(width=800, height=400, background_color='white', colormap='Greens', stopwords=custom_stopwords).generate(gulf_positive_text)

# For negative reviews
wordcloud_negative_filtered = WordCloud(width=800, height=400, background_color='white', colormap='Reds', stopwords=custom_stopwords).generate(gulf_negative_text)

# %%
#Positive
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_positive_filtered, interpolation='bilinear')
plt.axis('off')
plt.title('Positive Reviews Word Cloud')
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_negative_filtered, interpolation='bilinear')
plt.axis('off')
plt.title('Negative Reviews Word Cloud')
plt.show()

# %%
# Filtering only negative reviews
negative_reviews = gulf_df[gulf_df['review_sentiment'] == 'negative'].copy()

# Defining the issue classification function
def classify_issue(text):
    if any(keyword in text for keyword in ['delay', 'cancel', 'late', 'reschedule']):
        return 'Flight Delay/Cancellation'
    elif any(keyword in text for keyword in ['baggage', 'luggage', 'lost bag', 'bag']):
        return 'Baggage Issue'
    elif any(keyword in text for keyword in ['booking', 'ticket', 'reservation', 'book']):
        return 'Booking Problem'
    elif any(keyword in text for keyword in ['rude', 'service', 'staff', 'crew', 'help']):
        return 'Customer Service Issue'
    elif any(keyword in text for keyword in ['seat', 'uncomfortable', 'legroom']):
        return 'Seat Comfort Issue'
    elif any(keyword in text for keyword in ['food', 'meal', 'entertainment']):
        return 'In-flight Service Issue'
    elif any(keyword in text for keyword in ['checkin', 'check-in', 'boarding', 'gate']):
        return 'Check-in/Boarding Issue'
    elif any(keyword in text for keyword in ['refund', 'payment', 'voucher', 'charged']):
        return 'Refund/Payment Issue'
    elif any(keyword in text for keyword in ['app', 'website', 'online']):
        return 'App/Website Issue'
    else:
        return 'Other/Uncategorized'

# Applying classification to only negative reviews
negative_reviews['issue_classification'] = negative_reviews['clean_review'].apply(classify_issue)

# Counting the issue types
issue_summary = negative_reviews['issue_classification'].value_counts().reset_index()
issue_summary.columns = ['issue_classification', 'count']
issue_summary

# %%
# List of categories to analyze
rating_columns = ['Seat Comfort', 'Cabin Staff Service', 'Food & Beverages', 'Ground Service', 'Value For Money']

# Calculating average ratings
median_ratings = gulf_df[rating_columns].median().sort_values()

# Plotting
plt.figure(figsize=(8, 5))
median_ratings.plot(kind='barh', color='darkorange')

plt.title('Average Rating by Category', fontsize=20, fontweight='bold', color='darkslategray')
plt.xlabel('Average Rating', fontsize=17)
plt.ylabel('')
plt.xlim(0, 10)  # Correct: horizontal chart -> limit x-axis
plt.xticks(rotation=0, fontsize=15)
plt.yticks(fontsize=15)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Filtering negative reviews only
negative_reviews = gulf_df[gulf_df['review_sentiment'] == 'negative']

# Generating trigrams
vectorizer = CountVectorizer(ngram_range=(3, 3), max_features=10)
X2 = vectorizer.fit_transform(negative_reviews['clean_review'])

# Counting trigrams
trigrams = vectorizer.get_feature_names_out()
counts = X2.sum(axis=0).A1
trigram_freq = pd.DataFrame({'Trigram': trigrams, 'Count': counts}).sort_values(by='Count', ascending=False)
trigram_freq.rename(columns={'Trigram': ''}, inplace=True)

# Plotting
plt.figure(figsize=(12, 6))
sns.barplot(data=trigram_freq, x='Count', y='', color='indianred')
plt.title('Most Repeated Complaints are Related to Staff', fontsize=24, fontweight='bold', color='darkred')
plt.xlabel('Count', fontsize=16)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.tight_layout()
plt.show()

# %%
# Calculating average rating per seat type
seat_order = gulf_df.groupby('Seat Type')['Overall_Rating'].median().sort_values(ascending=False).index

# Plot the sorted boxplot
plt.figure(figsize=(10, 7))
sns.boxplot(data=airlines_df, x='Overall_Rating', y='Seat Type', palette='viridis', order=seat_order)
plt.title('Business Class Passengers Gave Higher Ratings', fontsize=25, fontweight='bold', color='darkslategray')
plt.xlabel('Average Rating', fontsize=20)
plt.ylabel('Seat Type', fontsize=20)
plt.xticks(fontsize=17)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Sorting type of traveller by average rating (descending)
traveller_order = gulf_df.groupby('Type Of Traveller')['Overall_Rating'].median().sort_values(ascending=False).index

# Plotting
plt.figure(figsize=(10, 6))
sns.boxplot(data=airlines_df, x='Overall_Rating', y='Type Of Traveller', palette='viridis', order=traveller_order)

plt.title('Solo and Business Travellers Gave Higher Ratings', fontsize=27, fontweight='bold', color='darkslategray')
plt.xlabel('Overall Rating', fontsize=20)
plt.ylabel('Type of Traveller', fontsize=20)
plt.xticks(fontsize=17)
plt.yticks(fontsize=15)
plt.xlim(0, 10) 
plt.grid(True, axis='x', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Done by: Sadia Liaqat
